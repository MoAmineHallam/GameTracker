# %% [markdown]
# # YOLO11 Football Detection — Training Notebook (Reproducible)
#
# This notebook contains the exact training workflow I used to train a YOLO11 model for football video analytics (players / referees / ball).
# I kept the code cells unchanged and organized the notebook so someone else can reproduce the run with minimal friction.
#
# ## What you get
# - Dataset download via Roboflow
# - YOLO training using Ultralytics
# - A clear checklist for setup and expected outputs
#
# ---
#
# ## Reproducibility checklist (read once)
# Before you run anything, verify:
#
# 1. **Python**: a clean environment (Conda or venv).
# 2. **GPU** (recommended): CUDA-ready PyTorch installed (otherwise training will be slow).
# 3. **Roboflow**: you have a Roboflow account + API key if required by your dataset script.
# 4. **Disk space**: dataset + runs/ checkpoints can be large.
#
# If you run into dependency conflicts, restart the kernel after installing packages.

# %% [markdown]
# ## 1) Environment setup
#
# The next cell installs Roboflow.
# If you already have it installed, you can still run it safely (pip will report it is already satisfied).

# %%
# !pip install roboflow

# %% [markdown]
# ## 2) Dataset download / preparation
#
# This section downloads the dataset and exposes the dataset path (`dataset.location`).
# If you change the dataset version or workspace/project name, update it inside the dataset code cell (I did not modify the code here).

# %% [markdown]
# # Get Dataset

# %%
#Get Dataset
from roboflow import Roboflow
rf = Roboflow(api_key="WOFiTmwYDTZ2ap6T2MjH")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Footballs-Player-Detection-3 in yolov11:: 100%|██████████| 2756/2756 [00:01<00:00, 2662.38it/s]

# %% [markdown]
# **Sanity check:** the next cell prints the resolved dataset location.
# You should see a local path on your machine (not mine).

# %%
dataset.location
# Out:
# 'C:\\Users\\Amine\\Desktop\\jupiter FinalProject\\football-players-detection-2'

# %% [markdown]
# ## 3) Training
#
# This section runs YOLO training using Ultralytics.
# Make sure you are using the same Ultralytics version you expect (training results can vary by version).
#
# Notes:
# - Training outputs will typically appear under a `runs/` directory (Ultralytics default).
# - If you want deterministic-ish runs, set seeds in your training cell (not changed here).

# %% [markdown]
# # Training

# %%
from ultralytics import YOLO

model = YOLO("yolo11m.pt")  # Load pre-trained model
results = model.train(
    data="C:\\Users\\Amine\\Desktop\\jupiter FinalProject\\football-players-detection-2\\data.yaml",
    epochs=10,
    imgsz=640,
)
# Out:
# Ultralytics 8.3.96  Python-3.12.3 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# ## 4) Outputs and next steps
#
# After training completes, you should have:
# - model checkpoints (e.g., best / last)
# - training logs (metrics curves, results CSV)
# - optional exported model formats if you export
#
# Use the final cell below for any post-training steps you already had (evaluation, export, quick inference).
# I kept it empty here because I used it as a scratch cell during experiments.
